# %%
import pandas as pd
from sqlalchemy import create_engine
import json

# 접속 정보 로딩 (옵션: db-config.json 파일이 있을 경우)
with open('db-config.json') as f:
    config = json.load(f)

user = config['user']
password = config['password']
host = config['host']
port = config['port']
database = config['database']

# SQLAlchemy 엔진 생성
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# weather 테이블 데이터 읽어오기
query_pollution = "SELECT * FROM air_pollution WHERE DATE(datetime) BETWEEN '2017-01-01' AND '2023-12-31'"
query_weather = "SELECT * FROM weather WHERE DATE(datetime) BETWEEN '2017-01-01' AND '2023-12-31'"
query_quality = "SELECT * FROM air_quality WHERE DATE(datetime) BETWEEN '2017-01-01' AND '2023-12-31'"
query_vehicle = "SELECT * FROM vehicle_reg_stats WHERE DATE(datetime) BETWEEN '2017-01-01' AND '2023-12-31'"
# query_vehicle = "SELECT * FROM vehicle_reg_stats WHERE DATE(datetime) BETWEEN '2017-01-01' AND '2023-12-31'"

df_pollution = pd.read_sql(query_pollution, con=engine)
df_weather = pd.read_sql(query_weather, con=engine)
df_quality = pd.read_sql(query_quality, con=engine)
df_vehicle = pd.read_sql(query_vehicle, con=engine)

# %%
df_quality.isna().sum()
# Out:
# id              0
# datetime        0
# region          0
# pm10        44421
# pm25        36312
# dtype: int64

# %%
df_quality
# Out:
#               id            datetime region  pm10  pm25
# 0         907342 2019-12-31 23:00:00     평균  23.0  15.0
# 1         907343 2019-12-31 23:00:00    강남구  19.0  15.0
# 2         907344 2019-12-31 23:00:00    강동구  25.0  18.0
# 3         907345 2019-12-31 23:00:00    강북구  25.0  16.0
# 4         907346 2019-12-31 23:00:00    강서구  29.0  17.0
# ...          ...                 ...    ...   ...   ...
# 1594937  2730539 2023-01-01 00:00:00    용산구  51.0  43.0
# 1594938  2730540 2023-01-01 00:00:00    은평구  54.0  37.0
# 1594939  2730541 2023-01-01 00:00:00    종로구  76.0  67.0
# 1594940  2730542 2023-01-01 00:00:00     중구  63.0  61.0
# 1594941  2730543 2023-01-01 00:00:00    중랑구  68.0  54.0
#
# [1594942 rows x 5 columns]

# %%
df_weather
# Out:
#               id  station_id station_name            datetime  temperature  \
# 0        2793492         400           강남 2017-01-01 01:00:00          1.4
# 1        2793493         400           강남 2017-01-01 02:00:00          1.2
# 2        2793494         400           강남 2017-01-01 03:00:00          0.5
# 3        2793495         400           강남 2017-01-01 04:00:00          0.6
# 4        2793496         400           강남 2017-01-01 05:00:00          0.4
# ...          ...         ...          ...                 ...          ...
# 1428133  4221625         889          현충원 2023-12-30 20:00:00          2.2
# 1428134  4221626         889          현충원 2023-12-30 21:00:00          2.2
# 1428135  4221627         889          현충원 2023-12-30 22:00:00          2.4
# 1428136  4221628         889          현충원 2023-12-30 23:00:00          2.6
# 1428137  4221629         889          현충원 2023-12-31 00:00:00          1.9
#
#          wind_direction  wind_speed  precipitation  humidity
# 0                  69.1         1.3            0.0      78.0
# 1                  66.2         1.6            0.0      80.0
# 2                  66.0         1.5            0.0      84.0
# 3                  63.4         0.5            0.0      86.0
# 4                  63.2         0.8            0.0      85.0
# ...                 ...         ...            ...       ...
# 1428133            78.1         0.6            0.0     100.0
# 1428134            90.3         0.6            0.5     100.0
# 1428135             0.0         0.4            0.0     100.0
# 1428136            49.8         0.6            0.0     100.0
# 1428137             0.0         0.2            0.5     100.0
#
# [1428138 rows x 9 columns]

# %%
#station_id 열 제거, station_name > region으로 이름 변경
df_weather.drop(['station_id'],axis=1,inplace=True)
df_weather.rename(columns={"station_name":"region"},inplace=True)

# %%
df_weather['region'].unique()
# Out:
# array(['강남', '서초', '강동', '송파', '강서', '양천', '도봉', '노원', '동대문', '중랑', '기상청',
#        '마포', '서대문', '광진', '성북', '용산', '은평', '금천', '한강', '중구', '성동', '북악산',
#        '구로', '강북*', '남현', '관악', '영등포', '현충원'], dtype=object)

# %%
df_weather.isna().sum()
# Out:
# id                     0
# region                 0
# datetime               0
# temperature         4258
# wind_direction      4904
# wind_speed          4408
# precipitation      10441
# humidity          441838
# dtype: int64

# %%
df_weather.drop(columns=['id'], axis=1, inplace=True)

# %%
station_to_gu = {
    '강남': '강남구',
    '서초': '서초구',
    '강동': '강동구',
    '송파': '송파구',
    '강서': '강서구',
    '양천': '양천구',
    '도봉': '도봉구',
    '노원': '노원구',
    '동대문': '동대문구',
    '중랑': '중랑구',
    '기상청': '동작구',
    '마포': '마포구',
    '서대문': '서대문구',
    '광진': '광진구',
    '성북': '성북구',
    '용산': '용산구',
    '은평': '은평구',
    '금천': '금천구',
    '한강': '영등포구',
    '중구': '중구',
    '성동': '성동구',
    '북악산': '종로구',
    '구로': '구로구',
    '강북*': '강북구',
    '남현': '관악구',
    '관악': '관악구',
    '영등포': '영등포구',
    '현충원': '동작구'
}

# %%
#station_to_gu에서 지정한 이름대로 region값 매핑
df_weather['region'] = df_weather['region'].map(station_to_gu)

# %%
df_weather = df_weather.groupby(['datetime','region'],as_index=False).mean()

# %%
df_weather
# Out:
#                    datetime region  temperature  wind_direction  wind_speed  \
# 0       2017-01-01 01:00:00    강남구          1.4           69.10        1.30
# 1       2017-01-01 01:00:00    강동구         -0.2          358.90        1.30
# 2       2017-01-01 01:00:00    강북구          1.4          338.80        0.50
# 3       2017-01-01 01:00:00    강서구          2.9          116.90        1.80
# 4       2017-01-01 01:00:00    관악구          1.1          178.25        1.75
# ...                     ...    ...          ...             ...         ...
# 1271549 2023-12-31 00:00:00   영등포구          2.9          161.70        2.10
# 1271550 2023-12-31 00:00:00    용산구          2.1           38.10        2.40
# 1271551 2023-12-31 00:00:00    은평구          2.8           61.00        1.10
# 1271552 2023-12-31 00:00:00     중구          0.4          176.40        4.70
# 1271553 2023-12-31 00:00:00    중랑구          2.5            0.00        0.40
#
#          precipitation  humidity
# 0                  0.0      78.0
# 1                  0.0      88.0
# 2                  0.0      81.0
# 3                  0.0       NaN
# 4                  0.0      93.0
# ...                ...       ...
# 1271549            0.0      93.5
# 1271550            0.0      94.0
# 1271551            0.0     100.0
# 1271552            0.0     100.0
# 1271553            0.0      94.0
#
# [1271554 rows x 7 columns]

# %%
df_pollution
# Out:
#               id            datetime region     no2    co     so2      o3
# 0          31704 2017-01-01 00:00:00     평균  0.0536  1.21  0.0054  0.0025
# 1          31705 2017-01-01 01:00:00     평균  0.0508  1.15  0.0053  0.0025
# 2          31706 2017-01-01 02:00:00     평균  0.0493  1.15  0.0051  0.0026
# 3          31707 2017-01-01 03:00:00     평균  0.0475  1.13  0.0049  0.0024
# 4          31708 2017-01-01 04:00:00     평균  0.0444  1.08  0.0047  0.0024
# ...          ...                 ...    ...     ...   ...     ...     ...
# 1576219  2352898 2023-12-31 19:00:00    중랑구  0.0310  0.67  0.0023  0.0142
# 1576220  2352899 2023-12-31 20:00:00    중랑구  0.0326  0.72  0.0022  0.0106
# 1576221  2352900 2023-12-31 21:00:00    중랑구  0.0352  0.76  0.0027  0.0087
# 1576222  2352901 2023-12-31 22:00:00    중랑구  0.0465  0.99  0.0026  0.0021
# 1576223  2352902 2023-12-31 23:00:00    중랑구  0.0476  1.10  0.0024  0.0018
#
# [1576224 rows x 7 columns]

# %%
df_pollution.isna().sum()
# Out:
# id          0
# datetime    0
# region      0
# no2         0
# co          0
# so2         0
# o3          0
# dtype: int64

# %%
df_pollution.drop(columns='id', inplace=True)

# %%
df_pollution
# Out:
#                    datetime region     no2    co     so2      o3
# 0       2017-01-01 00:00:00     평균  0.0536  1.21  0.0054  0.0025
# 1       2017-01-01 01:00:00     평균  0.0508  1.15  0.0053  0.0025
# 2       2017-01-01 02:00:00     평균  0.0493  1.15  0.0051  0.0026
# 3       2017-01-01 03:00:00     평균  0.0475  1.13  0.0049  0.0024
# 4       2017-01-01 04:00:00     평균  0.0444  1.08  0.0047  0.0024
# ...                     ...    ...     ...   ...     ...     ...
# 1576219 2023-12-31 19:00:00    중랑구  0.0310  0.67  0.0023  0.0142
# 1576220 2023-12-31 20:00:00    중랑구  0.0326  0.72  0.0022  0.0106
# 1576221 2023-12-31 21:00:00    중랑구  0.0352  0.76  0.0027  0.0087
# 1576222 2023-12-31 22:00:00    중랑구  0.0465  0.99  0.0026  0.0021
# 1576223 2023-12-31 23:00:00    중랑구  0.0476  1.10  0.0024  0.0018
#
# [1576224 rows x 6 columns]

# %%
df_vehicle
# Out:
#          id   datetime region fuel_type use_type  reg_count
# 0       136 2017-01-01     강원        경유      사업용    12362.0
# 1       137 2017-01-01     광주        전기     비사업용      240.0
# 2       138 2017-01-01     인천        전기      사업용        6.0
# 3       139 2017-01-01     인천        전기     비사업용      210.0
# 4       140 2017-01-01     대구        전기      사업용       53.0
# ...     ...        ...    ...       ...      ...        ...
# 9931  10067 2023-12-01     경남       휘발유      사업용    52259.0
# 9932  10068 2023-12-01     경북       휘발유      사업용     1802.0
# 9933  10069 2023-12-01     대구        경유      사업용    24774.0
# 9934  10070 2023-12-01     부산       휘발유      사업용    53741.0
# 9935  10071 2023-12-01     충북        경유     비사업용   351701.0
#
# [9936 rows x 6 columns]

# %%
df_vehicle = df_vehicle.groupby(['datetime', 'region', 'fuel_type'], as_index=False)['reg_count'].sum()

# %%
df_vehicle
# Out:
#        datetime region fuel_type  reg_count
# 0    2017-01-01     강원        경유   342173.0
# 1    2017-01-01     강원        전기      157.0
# 2    2017-01-01     강원       휘발유   305859.0
# 3    2017-01-01     경기        경유  2190457.0
# 4    2017-01-01     경기        전기      707.0
# ...         ...    ...       ...        ...
# 4531 2023-12-01     충남        전기    24130.0
# 4532 2023-12-01     충남       휘발유   555127.0
# 4533 2023-12-01     충북        경유   372795.0
# 4534 2023-12-01     충북        전기    19972.0
# 4535 2023-12-01     충북       휘발유   421862.0
#
# [4536 rows x 4 columns]

# %%
df_vehicle['year'] = pd.to_datetime(df_vehicle['datetime']).dt.year
df_vehicle['month'] = pd.to_datetime(df_vehicle['datetime']).dt.month

# %%
from pandas.tseries.offsets import MonthEnd

df_vehicle['start_date'] = pd.to_datetime(df_vehicle['datetime'])  # 1일
df_vehicle['end_date'] = df_vehicle['start_date'] + MonthEnd(0)   # 말일

# 일자 리스트 생성
date_rows = []

for _, row in df_vehicle.iterrows():
    days = pd.date_range(start=row['start_date'], end=row['end_date'], freq='D')
    for day in days:
        date_rows.append({
            'date': day,
            'region': row['region'],
            'fuel_type': row['fuel_type'],
            'reg_count': row['reg_count'],
        })

daily_df = pd.DataFrame(date_rows)

# %%
vehicle_seoul = daily_df[daily_df['region'] == '서울'].copy()
vehicle_seoul
# Out:
#              date region fuel_type  reg_count
# 837    2017-01-01     서울        경유  1112698.0
# 838    2017-01-02     서울        경유  1112698.0
# 839    2017-01-03     서울        경유  1112698.0
# 840    2017-01-04     서울        경유  1112698.0
# 841    2017-01-05     서울        경유  1112698.0
# ...           ...    ...       ...        ...
# 137275 2023-12-27     서울       휘발유  1658706.0
# 137276 2023-12-28     서울       휘발유  1658706.0
# 137277 2023-12-29     서울       휘발유  1658706.0
# 137278 2023-12-30     서울       휘발유  1658706.0
# 137279 2023-12-31     서울       휘발유  1658706.0
#
# [7668 rows x 4 columns]

# %%
hours = pd.date_range("00:00", "23:00", freq="h").time
hour_df = pd.DataFrame({'time': hours})

# 일 × 시 조합
expanded = vehicle_seoul.merge(hour_df, how='cross')
expanded['datetime'] = pd.to_datetime(expanded['date'].astype(str) + ' ' + expanded['time'].astype(str))

# 정리
expanded = expanded[['datetime', 'region', 'fuel_type', 'reg_count']].sort_values('datetime').reset_index(drop=True)

# %%
expanded
# Out:
#                   datetime region fuel_type  reg_count
# 0      2017-01-01 00:00:00     서울        경유  1112698.0
# 1      2017-01-01 00:00:00     서울        전기     1589.0
# 2      2017-01-01 00:00:00     서울       휘발유  1600398.0
# 3      2017-01-01 01:00:00     서울        경유  1112698.0
# 4      2017-01-01 01:00:00     서울        전기     1589.0
# ...                    ...    ...       ...        ...
# 184027 2023-12-31 22:00:00     서울       휘발유  1658706.0
# 184028 2023-12-31 22:00:00     서울        경유  1008457.0
# 184029 2023-12-31 23:00:00     서울        전기    72937.0
# 184030 2023-12-31 23:00:00     서울        경유  1008457.0
# 184031 2023-12-31 23:00:00     서울       휘발유  1658706.0
#
# [184032 rows x 4 columns]

# %%
df_vehicle = expanded
df_vehicle.drop(['region'], axis=1,inplace=True)

# %%
df_pollution.to_csv("대기오염.csv",index=False)
df_weather.to_csv("날씨.csv",index=False)
df_quality.to_csv("대기질.csv",index=False)
df_vehicle.to_csv("차량.csv",index=False)

# %%
df1 = pd.read_csv("./대기오염.csv")
df2 = pd.read_csv("./날씨.csv")
df3 = pd.read_csv("./대기질.csv")
df4 = pd.read_csv("./차량.csv")

# %%
df_merged = pd.merge(df1, df2)
df_merged = pd.merge(df_merged, df3)

# %%
df_merged = pd.merge(df_merged,df4)

# %%
df = df_merged
df
# Out:
#                     datetime region     no2    co     so2      o3  \
# 0        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 1        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 2        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 3        2017-01-01 02:00:00    강남구  0.0380  0.80  0.0050  0.0020
# 4        2017-01-01 02:00:00    강남구  0.0380  0.80  0.0050  0.0020
# ...                      ...    ...     ...   ...     ...     ...
# 3762538  2023-12-30 23:00:00    중랑구  0.0215  0.43  0.0023  0.0213
# 3762539  2023-12-30 23:00:00    중랑구  0.0215  0.43  0.0023  0.0213
# 3762540  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
# 3762541  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
# 3762542  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
#
#          temperature  wind_direction  wind_speed  precipitation  humidity  \
# 0                1.4            69.1         1.3            0.0      78.0
# 1                1.4            69.1         1.3            0.0      78.0
# 2                1.4            69.1         1.3            0.0      78.0
# 3                1.2            66.2         1.6            0.0      80.0
# 4                1.2            66.2         1.6            0.0      80.0
# ...              ...             ...         ...            ...       ...
# 3762538          2.3           350.8         1.7            0.0      93.0
# 3762539          2.3           350.8         1.7            0.0      93.0
# 3762540          2.5             0.0         0.4            0.0      94.0
# 3762541          2.5             0.0         0.4            0.0      94.0
# 3762542          2.5             0.0         0.4            0.0      94.0
#
#               id  pm10  pm25 fuel_type  reg_count
# 0        1590571  63.0  48.0        경유  1112698.0
# 1        1590571  63.0  48.0        전기     1589.0
# 2        1590571  63.0  48.0       휘발유  1600398.0
# 3        1590545  61.0  44.0        경유  1112698.0
# 4        1590545  61.0  44.0        전기     1589.0
# ...          ...   ...   ...       ...        ...
# 3762538  2503433  32.0  23.0        전기    72937.0
# 3762539  2503433  32.0  23.0        경유  1008457.0
# 3762540  2503407  29.0  23.0        전기    72937.0
# 3762541  2503407  29.0  23.0        경유  1008457.0
# 3762542  2503407  29.0  23.0       휘발유  1658706.0
#
# [3762543 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# datetime                0
# region                  0
# no2                     0
# co                      0
# so2                     0
# o3                      0
# temperature         10953
# wind_direction      10011
# wind_speed           8913
# precipitation       23682
# humidity          1077750
# id                      0
# pm10               112689
# pm25                92265
# fuel_type               0
# reg_count               0
# dtype: int64

# %%
#datetime, region을 기준으로 오름차순 정렬
df = df.sort_values(by=['datetime','region'])

# %%
df
# Out:
#                     datetime region     no2    co     so2      o3  \
# 0        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 1        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 2        2017-01-01 01:00:00    강남구  0.0400  0.80  0.0050  0.0020
# 154263   2017-01-01 01:00:00    강동구  0.0420  0.90  0.0040  0.0020
# 154264   2017-01-01 01:00:00    강동구  0.0420  0.90  0.0040  0.0020
# ...                      ...    ...     ...   ...     ...     ...
# 3607939  2023-12-31 00:00:00     중구  0.0298  0.55  0.0029  0.0161
# 3607940  2023-12-31 00:00:00     중구  0.0298  0.55  0.0029  0.0161
# 3762540  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
# 3762541  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
# 3762542  2023-12-31 00:00:00    중랑구  0.0270  0.51  0.0025  0.0170
#
#          temperature  wind_direction  wind_speed  precipitation  humidity  \
# 0                1.4            69.1         1.3            0.0      78.0
# 1                1.4            69.1         1.3            0.0      78.0
# 2                1.4            69.1         1.3            0.0      78.0
# 154263          -0.2           358.9         1.3            0.0      88.0
# 154264          -0.2           358.9         1.3            0.0      88.0
# ...              ...             ...         ...            ...       ...
# 3607939          0.4           176.4         4.7            0.0     100.0
# 3607940          0.4           176.4         4.7            0.0     100.0
# 3762540          2.5             0.0         0.4            0.0      94.0
# 3762541          2.5             0.0         0.4            0.0      94.0
# 3762542          2.5             0.0         0.4            0.0      94.0
#
#               id  pm10  pm25 fuel_type  reg_count
# 0        1590571  63.0  48.0        경유  1112698.0
# 1        1590571  63.0  48.0        전기     1589.0
# 2        1590571  63.0  48.0       휘발유  1600398.0
# 154263   1590572  68.0  53.0        경유  1112698.0
# 154264   1590572  68.0  53.0        전기     1589.0
# ...          ...   ...   ...       ...        ...
# 3607939  2503406  30.0  27.0        경유  1008457.0
# 3607940  2503406  30.0  27.0       휘발유  1658706.0
# 3762540  2503407  29.0  23.0        전기    72937.0
# 3762541  2503407  29.0  23.0        경유  1008457.0
# 3762542  2503407  29.0  23.0       휘발유  1658706.0
#
# [3762543 rows x 16 columns]

# %%
#원하는 소수점 자릿수로 강제로 고정
# df['no2'] = df['no2'].map(lambda x: f"{x:.3f}")
df['no2'] = df['no2'].map(lambda x: f"{x:.3f}")
df['co'] = df['co'].map(lambda x: f"{x:.1f}")
df['so2'] = df['so2'].map(lambda x: f"{x:.3f}")
df['o3'] = df['o3'].map(lambda x: f"{x:.3f}")
df['temperature'] = df['temperature'].map(lambda x: f"{x:.1f}")
df['wind_direction'] = df['wind_direction'].map(lambda x: f"{x:.1f}")
df['wind_speed'] = df['wind_speed'].map(lambda x: f"{x:.1f}")
df['precipitation'] = df['precipitation'].map(lambda x: f"{x:.1f}")
df['humidity'] = df['humidity'].map(lambda x: f"{x:.0f}")
df['pm10'] = df['pm10'].map(lambda x: f"{x:.0f}")
df['pm25'] = df['pm25'].map(lambda x: f"{x:.0f}")
df['reg_count'] = df['reg_count'].map(lambda x: f"{x:.0f}")

# %%
df
# Out:
#                     datetime region    no2   co    so2     o3 temperature  \
# 0        2017-01-01 01:00:00    강남구  0.040  0.8  0.005  0.002         1.4
# 1        2017-01-01 01:00:00    강남구  0.040  0.8  0.005  0.002         1.4
# 2        2017-01-01 01:00:00    강남구  0.040  0.8  0.005  0.002         1.4
# 154263   2017-01-01 01:00:00    강동구  0.042  0.9  0.004  0.002        -0.2
# 154264   2017-01-01 01:00:00    강동구  0.042  0.9  0.004  0.002        -0.2
# ...                      ...    ...    ...  ...    ...    ...         ...
# 3607939  2023-12-31 00:00:00     중구  0.030  0.6  0.003  0.016         0.4
# 3607940  2023-12-31 00:00:00     중구  0.030  0.6  0.003  0.016         0.4
# 3762540  2023-12-31 00:00:00    중랑구  0.027  0.5  0.003  0.017         2.5
# 3762541  2023-12-31 00:00:00    중랑구  0.027  0.5  0.003  0.017         2.5
# 3762542  2023-12-31 00:00:00    중랑구  0.027  0.5  0.003  0.017         2.5
#
#         wind_direction wind_speed precipitation humidity       id pm10 pm25  \
# 0                 69.1        1.3           0.0       78  1590571   63   48
# 1                 69.1        1.3           0.0       78  1590571   63   48
# 2                 69.1        1.3           0.0       78  1590571   63   48
# 154263           358.9        1.3           0.0       88  1590572   68   53
# 154264           358.9        1.3           0.0       88  1590572   68   53
# ...                ...        ...           ...      ...      ...  ...  ...
# 3607939          176.4        4.7           0.0      100  2503406   30   27
# 3607940          176.4        4.7           0.0      100  2503406   30   27
# 3762540            0.0        0.4           0.0       94  2503407   29   23
# 3762541            0.0        0.4           0.0       94  2503407   29   23
# 3762542            0.0        0.4           0.0       94  2503407   29   23
#
#         fuel_type reg_count
# 0              경유   1112698
# 1              전기      1589
# 2             휘발유   1600398
# 154263         경유   1112698
# 154264         전기      1589
# ...           ...       ...
# 3607939        경유   1008457
# 3607940       휘발유   1658706
# 3762540        전기     72937
# 3762541        경유   1008457
# 3762542       휘발유   1658706
#
# [3762543 rows x 16 columns]

# %%
fuel_map = {
    '경유': 'diesel',
    '전기': 'electric',
    '휘발유': 'gasoline'
}
df['fuel_type'] = df['fuel_type'].map(fuel_map)

# 1. fuel_type별 reg_count 피벗
df_fuel = df.pivot_table(
    index=['datetime', 'region'],
    columns='fuel_type',
    values='reg_count',
    aggfunc='sum'
).reset_index()

# 2. columns 정리
df_fuel.columns.name = None

# 3. 원래 df에서 fuel_type과 reg_count만 제거
df_base = df.drop(columns=['fuel_type', 'reg_count']).drop_duplicates()

# 4. 원래 df와 연료 피벗 결과를 merge
df_final = pd.merge(df_base, df_fuel, on=['datetime', 'region'], how='left')

# %%
df_final
# Out:
#                     datetime region    no2   co    so2     o3 temperature  \
# 0        2017-01-01 01:00:00    강남구  0.040  0.8  0.005  0.002         1.4
# 1        2017-01-01 01:00:00    강동구  0.042  0.9  0.004  0.002        -0.2
# 2        2017-01-01 01:00:00    강북구  0.046  1.2  0.004  0.001         1.4
# 3        2017-01-01 01:00:00    강서구  0.070  1.3  0.007  0.002         2.9
# 4        2017-01-01 01:00:00    관악구  0.075  1.5  0.006  0.004         1.1
# ...                      ...    ...    ...  ...    ...    ...         ...
# 1253600  2023-12-31 00:00:00   영등포구  0.031  0.6  0.002  0.014         2.9
# 1253601  2023-12-31 00:00:00    용산구  0.034  0.6  0.002  0.010         2.1
# 1253602  2023-12-31 00:00:00    은평구  0.009  0.9  0.002  0.031         2.8
# 1253603  2023-12-31 00:00:00     중구  0.030  0.6  0.003  0.016         0.4
# 1253604  2023-12-31 00:00:00    중랑구  0.027  0.5  0.003  0.017         2.5
#
#         wind_direction wind_speed precipitation humidity       id pm10 pm25  \
# 0                 69.1        1.3           0.0       78  1590571   63   48
# 1                358.9        1.3           0.0       88  1590572   68   53
# 2                338.8        0.5           0.0       81  1590573   63   51
# 3                116.9        1.8           0.0      nan  1590574  107   65
# 4                178.2        1.8           0.0       93  1590575   75   57
# ...                ...        ...           ...      ...      ...  ...  ...
# 1253600          161.7        2.1           0.0       94  2503402   40   34
# 1253601           38.1        2.4           0.0       94  2503403   31   18
# 1253602           61.0        1.1           0.0      100  2503404   40   25
# 1253603          176.4        4.7           0.0      100  2503406   30   27
# 1253604            0.0        0.4           0.0       94  2503407   29   23
#
#           diesel electric gasoline
# 0        1112698     1589  1600398
# 1        1112698     1589  1600398
# 2        1112698     1589  1600398
# 3        1112698     1589  1600398
# 4        1112698     1589  1600398
# ...          ...      ...      ...
# 1253600  1008457    72937  1658706
# 1253601  1008457    72937  1658706
# 1253602  1008457    72937  1658706
# 1253603  1008457    72937  1658706
# 1253604  1008457    72937  1658706
#
# [1253605 rows x 17 columns]

# %%
df=df_final

# %%
df.to_csv("./대기오염물질_데이터셋.csv",index=False)
