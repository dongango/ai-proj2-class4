# %%
import pymysql
import pandas as pd
import numpy as np
import json
import io
import tempfile  
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from datetime import timedelta

# %%
# 전역 설정
INPUT_LEN = 365
PREDICT_DAYS = 7

REGIONS = [
    '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
    '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
    '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'
]
POLLUTIONS = ['pm10', 'pm25']

# %%
# DB config 로드
with open('db-config.json', encoding='utf-8') as f:
    DB_CONFIG = json.load(f)

def get_connection():
    return pymysql.connect(
        host=DB_CONFIG['host'],
        user=DB_CONFIG['user'],
        password=DB_CONFIG['password'],
        database=DB_CONFIG['database'],
        port=DB_CONFIG.get('port', 3306),
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )

# %%
def predict_for_region_pollution(region, pollution):
    conn = get_connection()
    try:
        with conn.cursor() as cursor:
            # 모델 로드
            model_name = f"lstm_{pollution}_{region}"
            cursor.execute("""
                SELECT data
                FROM models
                WHERE name = %s
                ORDER BY created_at DESC
                LIMIT 1
            """, (model_name,))
            row = cursor.fetchone()
            if row is None:
                print(f"모델 없음: {model_name}")
                return None
            
            model_binary = row['data']
            with tempfile.NamedTemporaryFile(delete=True, suffix=".h5") as tmp:
                tmp.write(model_binary)
                tmp.flush()
                lstm_model = load_model(tmp.name, compile=False)

            print(f"모델 로드 완료: {model_name}")

            # 어제 기준 최신 365일 데이터 로드
            cursor.execute(f"""
                SELECT datetime, {pollution}
                FROM air_quality
                WHERE region = %s
                  AND datetime < CURDATE()
                ORDER BY datetime DESC
                LIMIT {INPUT_LEN}
            """, (region,))
            rows = cursor.fetchall()
            if len(rows) < INPUT_LEN:
                print(f"데이터 부족: {region} - {pollution}")
                return None
            
            df = pd.DataFrame(rows).sort_values('datetime')

            # 정규화
            scaler = MinMaxScaler()
            X_scaled = scaler.fit_transform(df[[pollution]].values)

            # 예측
            input_seq = X_scaled.reshape(1, INPUT_LEN, 1)
            preds = lstm_model.predict(input_seq, verbose=0)  # (1,30)
            preds_inverse = scaler.inverse_transform(preds.reshape(-1, 1))  # (30,1)

            start_date = df['datetime'].iloc[-1] + timedelta(days=1)

            predictions = []
            for i in range(PREDICT_DAYS):
                predictions.append({
                    'datetime': start_date + timedelta(days=i),
                    'region': region,
                    'pollution': pollution,
                    'value': float(preds_inverse[i, 0])
                })

            return predictions

    finally:
        conn.close()

# %%
if __name__ == "__main__":
    results = []

    for region in REGIONS:
        for pollution in POLLUTIONS:
            preds = predict_for_region_pollution(region, pollution)
            if preds is not None:
                results.extend(preds)

    result_df = pd.DataFrame(results)
    print(result_df)

    # 결과 CSV 저장 (선택)
    # result_df.to_csv("air_quality_predictions.csv", index=False)
# Out:
# ✅ 모델 로드 완료: lstm_pm10_강남구
# ✅ 모델 로드 완료: lstm_pm25_강남구
# ✅ 모델 로드 완료: lstm_pm10_강동구
# ✅ 모델 로드 완료: lstm_pm25_강동구
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x354d20f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ✅ 모델 로드 완료: lstm_pm10_강북구
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x354dd63e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ✅ 모델 로드 완료: lstm_pm25_강북구
# ✅ 모델 로드 완료: lstm_pm10_강서구
# ✅ 모델 로드 완료: lstm_pm25_강서구
# ✅ 모델 로드 완료: lstm_pm10_관악구
# ✅ 모델 로드 완료: lstm_pm25_관악구
# ✅ 모델 로드 완료: lstm_pm10_광진구
# ✅ 모델 로드 완료: lstm_pm25_광진구
# ✅ 모델 로드 완료: lstm_pm10_구로구
# ✅ 모델 로드 완료: lstm_pm25_구로구
# ✅ 모델 로드 완료: lstm_pm10_금천구
# ✅ 모델 로드 완료: lstm_pm25_금천구
# ✅ 모델 로드 완료: lstm_pm10_노원구
# ✅ 모델 로드 완료: lstm_pm25_노원구
# ✅ 모델 로드 완료: lstm_pm10_도봉구
# ✅ 모델 로드 완료: lstm_pm25_도봉구
# ✅ 모델 로드 완료: lstm_pm10_동대문구
# ✅ 모델 로드 완료: lstm_pm25_동대문구
# ✅ 모델 로드 완료: lstm_pm10_동작구
# ⚠️ 모델 없음: lstm_pm25_동작구
# ✅ 모델 로드 완료: lstm_pm10_마포구
# ✅ 모델 로드 완료: lstm_pm25_마포구
# ✅ 모델 로드 완료: lstm_pm10_서대문구
# ✅ 모델 로드 완료: lstm_pm25_서대문구
# ✅ 모델 로드 완료: lstm_pm10_서초구
# ✅ 모델 로드 완료: lstm_pm25_서초구
# ✅ 모델 로드 완료: lstm_pm10_성동구
# ✅ 모델 로드 완료: lstm_pm25_성동구
# ✅ 모델 로드 완료: lstm_pm10_성북구
# ✅ 모델 로드 완료: lstm_pm25_성북구
# ✅ 모델 로드 완료: lstm_pm10_송파구
# ✅ 모델 로드 완료: lstm_pm25_송파구
# ✅ 모델 로드 완료: lstm_pm10_양천구
# ✅ 모델 로드 완료: lstm_pm25_양천구
# ✅ 모델 로드 완료: lstm_pm10_영등포구
# ✅ 모델 로드 완료: lstm_pm25_영등포구
# ✅ 모델 로드 완료: lstm_pm10_용산구
# ✅ 모델 로드 완료: lstm_pm25_용산구
# ✅ 모델 로드 완료: lstm_pm10_은평구
# ✅ 모델 로드 완료: lstm_pm25_은평구
# ✅ 모델 로드 완료: lstm_pm10_종로구
# ✅ 모델 로드 완료: lstm_pm25_종로구
# ✅ 모델 로드 완료: lstm_pm10_중구
# ✅ 모델 로드 완료: lstm_pm25_중구
# ✅ 모델 로드 완료: lstm_pm10_중랑구
# ✅ 모델 로드 완료: lstm_pm25_중랑구
#                datetime region pollution      value
# 0   2025-07-03 23:00:00    강남구      pm10   7.456163
# 1   2025-07-04 23:00:00    강남구      pm10  10.181804
# 2   2025-07-05 23:00:00    강남구      pm10   7.930998
# 3   2025-07-06 23:00:00    강남구      pm10  -0.415487
# 4   2025-07-07 23:00:00    강남구      pm10   1.875089
# ..                  ...    ...       ...        ...
# 338 2025-07-05 23:00:00    중랑구      pm25  -3.675292
# 339 2025-07-06 23:00:00    중랑구      pm25   3.572223
# 340 2025-07-07 23:00:00    중랑구      pm25   1.113288
# 341 2025-07-08 23:00:00    중랑구      pm25  -1.900718
# 342 2025-07-09 23:00:00    중랑구      pm25   2.469680
#
# [343 rows x 4 columns]
